# %%
import matplotlib.pyplot as plt

categories = ['pants', 'shirts', 'outerwear', 'pajamas', 'underwear', 'shoes']

revenue = [25, 15, 5, 20, 10, 25]

# %%
plt.pie(revenue)
plt.show()

# %%
plt.pie(revenue, labels=categories)
plt.legend
plt.show()

# %%
plt.pie(revenue, labels=categories, autopct="%1.1f%%")
# Out:
# ([<matplotlib.patches.Wedge at 0x1965dc40970>,
#   <matplotlib.patches.Wedge at 0x1965e51feb0>,
#   <matplotlib.patches.Wedge at 0x1965e012b80>,
#   <matplotlib.patches.Wedge at 0x1965dc59a30>,
#   <matplotlib.patches.Wedge at 0x1965e44e130>,
#   <matplotlib.patches.Wedge at 0x1965e016e20>],
#  [Text(0.7778174593052024, 0.7778174593052024, 'pants'),
#   Text(-0.4993895680663527, 0.9801071672559598, 'shirts'),
#   Text(-0.9801071964785992, 0.499389510713692, 'outerwear'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'pajamas'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'underwear'),
#   Text(0.7778175139235951, -0.7778174046868057, 'shoes')],
#  [Text(0.4242640687119285, 0.4242640687119285, '25.0000000000%'),
#   Text(-0.2723943098543742, 0.5346039094123416, '15.0000005960%'),
#   Text(-0.5346039253519631, 0.27239427857110465, '5.0000000745%'),
#   Text(-0.5706339002294459, -0.18541022600959953, '20.0000002980%'),
#   Text(-0.1854101592263464, -0.5706339219286397, '10.0000001490%'),
#   Text(0.4242640985037791, -0.4242640389200758, '25.0000000000%')])

# %%
explode = [0, .3, 0, 0, 0, 0]
plt.pie(revenue, labels=categories, autopct="%1.1f%%", explode=explode)
# Out:
# ([<matplotlib.patches.Wedge at 0x1965ebf7160>,
#   <matplotlib.patches.Wedge at 0x1965d9c8fd0>,
#   <matplotlib.patches.Wedge at 0x1965a061fa0>,
#   <matplotlib.patches.Wedge at 0x1965eb44970>,
#   <matplotlib.patches.Wedge at 0x1965eb442b0>,
#   <matplotlib.patches.Wedge at 0x1965eb42b50>],
#  [Text(0.7778174593052024, 0.7778174593052024, 'pants'),
#   Text(-0.6355867229935398, 1.2474091219621306, 'shirts'),
#   Text(-0.9801071964785992, 0.499389510713692, 'outerwear'),
#   Text(-1.0461621504206509, -0.33991874768426583, 'pajamas'),
#   Text(-0.33991862524830174, -1.0461621902025062, 'underwear'),
#   Text(0.7778175139235951, -0.7778174046868057, 'shoes')],
#  [Text(0.4242640687119285, 0.4242640687119285, '25.0%'),
#   Text(-0.4085914647815613, 0.8019058641185124, '15.0%'),
#   Text(-0.5346039253519631, 0.27239427857110465, '5.0%'),
#   Text(-0.5706339002294459, -0.18541022600959953, '20.0%'),
#   Text(-0.1854101592263464, -0.5706339219286397, '10.0%'),
#   Text(0.4242640985037791, -0.4242640389200758, '25.0%')])
